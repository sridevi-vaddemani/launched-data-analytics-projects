# %%
# by using sales prediction 
# !pip install plotlty
# !pip install xgboost
# Out:
# ERROR: Could not find a version that satisfies the requirement plotlty (from versions: none)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for plotlty
# ...
#   Using cached xgboost-3.0.2-py3-none-win_amd64.whl.metadata (2.1 kB)
# ...
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
# ...

# %%
# !pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install statsmodels
import statsmodels.api as sm
print(sm.__version__)
# Out:
# ...
# 0.14.4
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sales_data=pd.read_excel("C:\\Users\\DELL\\Downloads\\sales price prediction_TV.xlsx")
sales_data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
data =pd.DataFrame(sales_data)
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
data.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
import plotly.express as px
import plotly.graph_objects as go
figure = px.scatter(data_frame = sales_data, x = "Sales",
                    y = "TV", size = "TV",trendline="ols")
figure.show()

# %%
figure = px.scatter(data_frame = sales_data, x="Sales",
                    y ="Newspaper",size ="Newspaper", trendline="ols")
figure.show()

# %%
figure= px.scatter(data_frame = sales_data, x="Sales",
                  y = "Radio",size="Radio", trendline="ols")
figure.show()

# %%
sales_corr = sales_data.corr()

# %%
sales_corr = sales_data.corr()
print(sales_corr["Sales"])
# Out:
# TV           0.901208
# Radio        0.349631
# Newspaper    0.157960
# Sales        1.000000
# Name: Sales, dtype: float64

# %%
feature_col= ["TV","Radio","Newspaper"]
x=sales_data [feature_col]
y=sales_data.Sales

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
display(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (160, 3)
# (160,)
# (40, 3)
# (40,)

# %%
print(x_train)
print(y_tarin)
# Out:
#         TV  Radio  Newspaper
# 79   116.0    7.7       23.1
# 197  177.0    9.3        6.4
# 38    43.1   26.7       35.1
# 24    62.3   12.6       18.3
# 122  224.0    2.4       15.6
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [160 rows x 3 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 print(x_train)
# ----> 2 print(y_tarin)
#
# NameError: name 'y_tarin' is not defined

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pandas as pd
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
print(y_pred)
print(y_test)
# Out:
# [17.0347724  20.40974033 23.72398873  9.27278518 21.68271879 12.56940161
#  21.08119452  8.69035045 17.23701254 16.66657475  8.92396497  8.4817344
#  18.2075123   8.06750728 12.64550975 14.93162809  8.12814594 17.89876565
#  11.00880637 20.47832788 20.80631846 12.59883297 10.9051829  22.38854775
#   9.41796094  7.92506736 20.83908497 13.81520938 10.77080925  7.92682509
#  15.95947357 10.63490851 20.80292008 10.43434164 21.5784752  21.18364487
#  12.12821771 22.80953262 12.60992766  6.46441252]
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    16.5
# 45     16.1
# 66     11.0
# 182     8.7
# 165    16.9
# 78      5.3
# 186    10.3
# 177    16.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65     11.3
# 60      8.1
# 84     21.7
# 67     13.4
# 125    10.6
# 132     5.7
# 9      15.6
# 18     11.3
# 55     23.7
# 75      8.7
# 150    16.1
# ...

# %%
feature=np.array([[100,90,60]])
print(model.predict(feature))
# Out:
# [19.51033491]
# C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

# %%
#r-sqr check
print("R_sqr values:", r2_score(y_pred,y_test))
# Out:
# R_sqr values: 0.896026527496257

# %%
print("mean abosulute error rate:", mean_absolute_error(y_pred,y_test))
# Out:
# mean abosulute error rate: 1.2748262109549338

# %%
print("mean_squared_error:",mean_squared_error(y_test,y_pred))
# Out:
# mean_squared_error: 2.9077569102710896

# %%
print("mean_squared_log_error:",mean_squared_log_error(y_pred,y_test))
# Out:
# mean_squared_log_error: 0.01720096860183206
